# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Elmo Allistair**<br>
# Data Science Student

# %% [markdown]
# *I am interested in data science because i have passion in data and it will help me in personal growth. Data Science also has potential to become sexiest job in this decade*

# %% [markdown]
# ### Hello World Project

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# # Markdown
#
# #### Horizontal rule
# <hr>
#
# #### Bulleted list
# * Item1
# * Item2
#
# #### Numbered list
# 1. Item1
# 2. Item2
#
# #### Tables
#
# | Name | Age |
# |------|-----|
# | John | 20  |
# | Doe  | 21  |
#
# #### Hyperlinks
# [Google](https://google.com)
#
# #### Code/Syntax
# `print("Hello, World")`
#
# #### Blocked quotes
# > Blocked quotes
#
# #### Strikethrough
# ~~Strikethrough~~
